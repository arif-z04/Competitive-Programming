# %%
import numpy as np
from sympy import Matrix

# %%
A = np.array(
    [
    [1, 0, -2, 1, 0],
    [0, -1, -3, 1, 3],
    [-2, -1, 1, -1, 3],
    ]
)
A = Matrix(A)
echelon_form = A.echelon_form()
Rank = A.rank()
print(echelon_form)
print(Rank)
# Out:
# Matrix([[1, 0, -2, 1, 0], [0, -1, -3, 1, 3], [0, 0, 0, 0, 0]])
# 2
